# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0d84ae5f-d5b6-47c6-9710-b15eb5f649d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d84ae5f-d5b6-47c6-9710-b15eb5f649d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Load the uploaded CSV file (replace with exact filename if needed)
df = pd.read_csv('Amazon Fashion.csv')

# Display the first few rows
df.head()
# Out:
#                                                 name main_category  \
# 0  Aqualogica Glow+ Dewy Sunscreen SPF 50 PA+++ F...        stores
# 1  MARVIK Soft Silicone Adjustable Band Strap Com...        stores
# 2  108 Panchatantra Stories for Children (Illustr...        stores
# 3  Black and White and Blue: Adult Cinema From th...        stores
# 4  SAFARI 15 Ltrs Sea Blue Casual/School/College ...        stores
#
#      sub_category                                              image  \
# 0  Amazon Fashion  https://m.media-amazon.com/images/I/51TSC6Uogx...
# 1  Amazon Fashion  https://m.media-amazon.com/images/I/51vYDop04S...
# 2  Amazon Fashion  https://m.media-amazon.com/images/I/81VJ+MAc7Y...
# 3  Amazon Fashion  https://m.media-amazon.com/images/I/51RIhaW3t1...
# 4  Amazon Fashion  https://m.media-amazon.com/images/I/61kmCas5OC...
#
#                                                 link ratings no_of_ratings  \
# ...

# %%
import pandas as pd
import numpy as np

# Just to verify they are working
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
# Out:
# Pandas version: 2.2.2
# NumPy version: 2.0.2

# %% [markdown]
# #1. Display First 5 Rows of the Dataset

# %%
df.head()
# Out:
#                                                 name main_category  \
# 0  Aqualogica Glow+ Dewy Sunscreen SPF 50 PA+++ F...        stores
# 1  MARVIK Soft Silicone Adjustable Band Strap Com...        stores
# 2  108 Panchatantra Stories for Children (Illustr...        stores
# 3  Black and White and Blue: Adult Cinema From th...        stores
# 4  SAFARI 15 Ltrs Sea Blue Casual/School/College ...        stores
#
#      sub_category                                              image  \
# 0  Amazon Fashion  https://m.media-amazon.com/images/I/51TSC6Uogx...
# 1  Amazon Fashion  https://m.media-amazon.com/images/I/51vYDop04S...
# 2  Amazon Fashion  https://m.media-amazon.com/images/I/81VJ+MAc7Y...
# 3  Amazon Fashion  https://m.media-amazon.com/images/I/51RIhaW3t1...
# 4  Amazon Fashion  https://m.media-amazon.com/images/I/61kmCas5OC...
#
#                                                 link ratings no_of_ratings  \
# ...

# %% [markdown]
# #2. Get Shape of the Dataset (Rows & Columns)

# %%
df.shape
# Out:
# (2352, 9)

# %% [markdown]
# #3. List All Column Names

# %%
df.columns.tolist()
# Out:
# ['name',
#  'main_category',
#  'sub_category',
#  'image',
#  'link',
#  'ratings',
#  'no_of_ratings',
#  'discount_price',
#  'actual_price']

# %% [markdown]
# #4. Check Data Types of Each Column

# %%
df.dtypes
# Out:
# name              object
# main_category     object
# sub_category      object
# image             object
# link              object
# ratings           object
# no_of_ratings     object
# discount_price    object
# actual_price      object
# dtype: object

# %% [markdown]
# #5. Count Missing Values in Each Column

# %%
df.isnull().sum()
# Out:
# name                0
# main_category       0
# sub_category        0
# image               0
# link                0
# ratings           206
# no_of_ratings     206
# discount_price    166
# actual_price       11
# dtype: int64

# %% [markdown]
# #6. Drop Rows with Any Missing Values

# %%
df = df.dropna()

# %% [markdown]
# #7. Find Total Number of Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #8. Drop All Duplicate Rows

# %%
df = df.drop_duplicates()

# %% [markdown]
# #9. Get Unique Values in a Categorical Column

# %%
df['actual_price'].unique()  # replace with actual column name
# Out:
# array(['₹399', '₹999', '₹160', '₹799', '₹499', '₹3,999', '₹3,495',
#        '₹1,262', '₹240', '₹2,100', '₹350', '₹1,499', '₹2,295', '₹1,799',
#        '₹125', '₹305', '₹600', '₹1,999', '₹540', '₹2,300', '₹500', '₹599',
#        '₹299', '₹750', '₹200', '₹29,990', '₹2,000', '₹76', '₹849',
#        '₹1,245', '₹80', '₹1,199', '₹4,999', '₹308', '₹145', '₹185',
#        '₹1,000', '₹13,200', '₹352', '₹995', '₹2,339', '₹900', '₹590',
#        '₹8,800', '₹549', '₹899', '₹1,099', '₹441', '₹2,995', '₹645',
#        '₹18,495', '₹740', '₹2,599', '₹486', '₹2,845', '₹375', '₹3,695',
#        '₹3,160', '₹225', '₹450', '₹5,995', '₹6,799', '₹479', '₹325',
#        '₹4,395', '₹349', '₹418', '₹3,299', '₹230', '₹1,299', '₹250',
#        '₹1,599', '₹699', '₹199', '₹1,995', '₹249', '₹2,999', '₹3,000',
#        '₹675', '₹72,800', '₹300', '₹11,999', '₹5,999', '₹465', '₹275',
#        '₹1,699', '₹2,899', '₹2,500', '₹344', '₹1,290', '₹700', '₹383',
# ...

# %% [markdown]
# #10. Top 10 Most Expensive Products by Actual Price

# %%
df.sort_values(by='actual_price', ascending=False).head(10)
# Out:
#                                                    name main_category  \
# 144   Bangalore Refinery 24k (999.9) 10 gm Yellow Go...        stores
# 447                    Studio Series Canvas Pencil Wrap        stores
# 36    Razer Anzu Smart Glasses: Blue Light Filtering...        stores
# 1469  Aristocrat Plastic Hard 75 Cms Luggage- Luggag...        stores
# 2197  kamiliant Harrier Spinner Polypropylene (PP) 3...        stores
# 692   American Tourister Ivy Spinner Polypropylene (...        stores
# 2278  Fossil Flynn Analog Black Dial Men's Watch-BQ2383        stores
# 1033  Maicrogear Swiss True High Tech Analogue Ceram...        stores
# 602   Casio G-Shock Analog-Digital Black Dial Men's ...        stores
# 78    Fossil Gen 5E Smartwatch with AMOLED Screen, W...        stores
#
#         sub_category                                              image  \
# 144   Amazon Fashion  https://m.media-amazon.com/images/I/61klNXLzIR...
# ...

# %% [markdown]
# #11.Top 10 Most Affordable Products by Discounted Price

# %%
df.sort_values(by='discount_price').head(10)
# Out:
#                                                    name main_category  \
# 1232  Himalaya Herbals Protecting Neem and Turmeric ...        stores
# 360   Om Jewells Rhodium Plated Glamorous Pink Drop ...        stores
# 1417  Kuber Industries Garbage Bag|Waste Bag|Garbage...        stores
# 39    Cherry Blossom Wax Shoe Polish Black - 40gm | ...        stores
# 1139  Swiss Beauty Eyebrow Definer Pencil with Spool...        stores
# 42    Blossom Moral Story Book for Kids 3 Years to 6...        stores
# 1043  Nivea Soft Light Moisturizer For Face, Hand & ...        stores
# 2008  NIVEA Body Lotion, Nourishing Body Milk, For V...        stores
# 488     Lakme Blush & Glow Strawberry Sheet Mask, 25 ml        stores
# 1338  Kraft Seeds Vermicompost 1 KG | Organic Manure...        stores
#
#         sub_category                                              image  \
# 1232  Amazon Fashion  https://m.media-amazon.com/images/W/IMAGERENDE...
# ...

# %% [markdown]
#  # 12.Count Products with Ratings >= 4.0

# %%
df[df['ratings'] >= 4.0].shape[0]
# Out:
# 1355

# %% [markdown]
# # 13. Top 10 Most Rated Products

# %%
df.sort_values(by='no_of_ratings', ascending=False).head(10)
# Out:
#                                                    name main_category  \
# 1112              crocs Unisex Crocband Clogs and Mules        stores
# 41    Pigeon by Stovekraft Amaze Plus Electric Kettl...        stores
# 6     Noise ColorFit Pulse Grand Smart Watch with 1....        stores
# 1268  Amazon Basics Micro Usb Fast Charging Cable Fo...        stores
# 1645  Amazon Basics 13mm Extra Thick NBR Yoga and Ex...        stores
# 316   Amazon Brand - Solimo Wax Tealight Candles (Se...        stores
# 483   Cello Checkers Plastic PET Canister Set, 18 Pi...        stores
# 709   GearLight LED Tactical Flashlight S1000 [2 Pac...        stores
# 195                 Parachute Coconut Oil - 1 L Pet Jar        stores
# 594   Maybelline New York Matte Lipstick, Intense Co...        stores
#
#         sub_category                                              image  \
# 1112  Amazon Fashion  https://m.media-amazon.com/images/I/61g5Zco3BK...
# ...

# %% [markdown]
# #14 Check Correlation Between Discount and Ratings

# %%
df[['discount_price', 'ratings']].corr()
# Out:
#                 discount_price   ratings
# discount_price        1.000000  0.141629
# ratings               0.141629  1.000000

# %% [markdown]
# #15.Create Column: Is Popular (Rating > 4 and Ratings > 1000)

# %%
df['is_popular'] = (df['ratings'] > 4.0) & (df['no_of_ratings'] > 1000)
# Out:
# <ipython-input-30-f3ba7b19b934>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_popular'] = (df['ratings'] > 4.0) & (df['no_of_ratings'] > 1000)

# %% [markdown]
# #16.How Many Products Have Ratings Below 3?

# %%
df[df['ratings'] < 3].shape[0]
# Out:
# 19

# %% [markdown]
# #17.Get Number of Products in Each Price Segment

# %%
df['actual_price'].value_counts()
# Out:
# actual_price
# 999.0      213
# 1999.0      92
# 1499.0      82
# 499.0       74
# 599.0       63
#           ...
# 2998.0       1
# 29250.0      1
# 3965.0       1
# 13659.0      1
# 10000.0      1
# Name: count, Length: 604, dtype: int64

# %% [markdown]
# #18.Find Products That Have No Ratings But High Price

# %%
df[df['ratings'].isnull() & (df['actual_price'] > 1000)]
# Out:
# Empty DataFrame
# Columns: [name, main_category, sub_category, image, link, ratings, no_of_ratings, discount_price, actual_price, is_popular]
# Index: []

# %% [markdown]
# #19.Calculate Discount Percentage

# %%
df['discount_percent'] = ((df['actual_price'] - df['discount_price']) / df['actual_price']) * 100
# Out:
# <ipython-input-35-a719867abb4d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['discount_percent'] = ((df['actual_price'] - df['discount_price']) / df['actual_price']) * 100

# %% [markdown]
# #20.Find Products with More Than 50% Discount

# %%
df[df['discount_percent'] > 50]
# Out:
#                                                    name main_category  \
# 1     MARVIK Soft Silicone Adjustable Band Strap Com...        stores
# 4     SAFARI 15 Ltrs Sea Blue Casual/School/College ...        stores
# 6     Noise ColorFit Pulse Grand Smart Watch with 1....        stores
# 7     New Fastrack Reflex Beat+ 1.69” UltraVU Displa...        stores
# 11    Brado Jewellery Multi Wearing Heart Necklace 4...        stores
# ...                                                 ...           ...
# 2338  GoSriKi Women's Cotton Blend Straight Printed ...        stores
# 2344  Clovia Cotton Rich Non-Wired Spacer Cup T-Shir...        stores
# 2345  Melbees by Yellow Chimes Unicorn Jewellery Set...        stores
# 2346                    Puma Mens Tiguan Slipon Sneaker        stores
# 2350  NAINVISH Women/Girl's Pure Cotton Paisley Prin...        stores
#
#         sub_category                                              image  \
# ...
